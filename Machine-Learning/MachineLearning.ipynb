# %% [markdown]
# # Glass Identification Data Set
# Attribute Information:
#    1. Id number: 1 to 214
#    2. RI: показатель преломления
#    3. Na: Натрий
#    4. Mg: Магний
#    5. Al: Алюминий
#    6. Si: Кремний
#    7. K: Калий
#    8. Ca: Кальций
#    9. Ba: Барий
#   10. Fe: Железо
#   11. Type of glass:
#       1.обработка окон с плавающей точкой
#       2.building_windows_non_float_processed
#       3.vehicle_windows_float_processed
#       4.vehicle_windows_non_float_processed (нет в таблице)
#       5.containers
#       6.tableware
#       7.headlamps

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline

# %% [markdown]
# Считывем данные из файла

# %%
data = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/glass/glass.data', sep = ',', engine = 'python')

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data
# Out:
#        1  1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.00  0.00.1  1.1
# 0      2  1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.00    0.00    1
# 1      3  1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.00    0.00    1
# 2      4  1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.00    0.00    1
# 3      5  1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.00    0.00    1
# 4      6  1.51596  12.79  3.61  1.62  72.97  0.64  8.07  0.00    0.26    1
# 5      7  1.51743  13.30  3.60  1.14  73.09  0.58  8.17  0.00    0.00    1
# 6      8  1.51756  13.15  3.61  1.05  73.24  0.57  8.24  0.00    0.00    1
# 7      9  1.51918  14.04  3.58  1.37  72.08  0.56  8.30  0.00    0.00    1
# 8     10  1.51755  13.00  3.60  1.36  72.99  0.57  8.40  0.00    0.11    1
# 9     11  1.51571  12.72  3.46  1.56  73.20  0.67  8.09  0.00    0.24    1
# 10    12  1.51763  12.80  3.66  1.27  73.01  0.60  8.56  0.00    0.00    1
# ...

# %%
data.columns = ['ID','RI','Na','Mg','Al','Si','K','Ca','Ba','Fe','class']
data
# Out:
#       ID       RI     Na    Mg    Al     Si     K    Ca    Ba    Fe  class
# 0      2  1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.00  0.00      1
# 1      3  1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.00  0.00      1
# 2      4  1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.00  0.00      1
# 3      5  1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.00  0.00      1
# 4      6  1.51596  12.79  3.61  1.62  72.97  0.64  8.07  0.00  0.26      1
# 5      7  1.51743  13.30  3.60  1.14  73.09  0.58  8.17  0.00  0.00      1
# 6      8  1.51756  13.15  3.61  1.05  73.24  0.57  8.24  0.00  0.00      1
# 7      9  1.51918  14.04  3.58  1.37  72.08  0.56  8.30  0.00  0.00      1
# 8     10  1.51755  13.00  3.60  1.36  72.99  0.57  8.40  0.00  0.11      1
# 9     11  1.51571  12.72  3.46  1.56  73.20  0.67  8.09  0.00  0.24      1
# 10    12  1.51763  12.80  3.66  1.27  73.01  0.60  8.56  0.00  0.00      1
# ...

# %%
print(data)
# Out:
#       ID       RI     Na    Mg    Al     Si     K    Ca    Ba    Fe  class
# 0      2  1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.00  0.00      1
# 1      3  1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.00  0.00      1
# 2      4  1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.00  0.00      1
# 3      5  1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.00  0.00      1
# 4      6  1.51596  12.79  3.61  1.62  72.97  0.64  8.07  0.00  0.26      1
# 5      7  1.51743  13.30  3.60  1.14  73.09  0.58  8.17  0.00  0.00      1
# 6      8  1.51756  13.15  3.61  1.05  73.24  0.57  8.24  0.00  0.00      1
# 7      9  1.51918  14.04  3.58  1.37  72.08  0.56  8.30  0.00  0.00      1
# 8     10  1.51755  13.00  3.60  1.36  72.99  0.57  8.40  0.00  0.11      1
# 9     11  1.51571  12.72  3.46  1.56  73.20  0.67  8.09  0.00  0.24      1
# 10    12  1.51763  12.80  3.66  1.27  73.01  0.60  8.56  0.00  0.00      1
# ...

# %%
data.head()
# Out:
#    ID       RI     Na    Mg    Al     Si     K    Ca   Ba    Fe  class
# 0   2  1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.0  0.00      1
# 1   3  1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.0  0.00      1
# 2   4  1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.0  0.00      1
# 3   5  1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.0  0.00      1
# 4   6  1.51596  12.79  3.61  1.62  72.97  0.64  8.07  0.0  0.26      1

# %%
data.tail()
# Out:
#       ID       RI     Na   Mg    Al     Si     K    Ca    Ba   Fe  class
# 208  210  1.51623  14.14  0.0  2.88  72.61  0.08  9.18  1.06  0.0      7
# 209  211  1.51685  14.92  0.0  1.99  73.06  0.00  8.40  1.59  0.0      7
# 210  212  1.52065  14.36  0.0  2.02  73.42  0.00  8.44  1.64  0.0      7
# 211  213  1.51651  14.38  0.0  1.94  73.61  0.00  8.48  1.57  0.0      7
# 212  214  1.51711  14.23  0.0  2.08  73.36  0.00  8.62  1.67  0.0      7

# %%
print(data.shape)
print(data.columns)
# Out:
# (213, 11)
# Index(['ID', 'RI', 'Na', 'Mg', 'Al', 'Si', 'K', 'Ca', 'Ba', 'Fe', 'class'], dtype='object')

# %%
data.index
# Out:
# RangeIndex(start=0, stop=213, step=1)

# %% [markdown]
# Основные характеристики.

# %%
data.describe()
# Out:
#                ID          RI          Na          Mg          Al          Si  \
# count  213.000000  213.000000  213.000000  213.000000  213.000000  213.000000
# mean   108.000000    1.518353   13.406761    2.676056    1.446526   72.655023
# std     61.631972    0.003039    0.818371    1.440453    0.499882    0.774052
# min      2.000000    1.511150   10.730000    0.000000    0.290000   69.810000
# 25%     55.000000    1.516520   12.900000    2.090000    1.190000   72.280000
# 50%    108.000000    1.517680   13.300000    3.480000    1.360000   72.790000
# 75%    161.000000    1.519150   13.830000    3.600000    1.630000   73.090000
# max    214.000000    1.533930   17.380000    3.980000    3.500000   75.410000
#
#                 K          Ca          Ba          Fe       class
# count  213.000000  213.000000  213.000000  213.000000  213.000000
# mean     0.499108    8.957934    0.175869    0.057277    2.788732
# std      0.653035    1.426435    0.498245    0.097589    2.105130
# ...

# %% [markdown]
# Диаграмма рассеивания

# %%
from pandas.plotting import scatter_matrix
scatter_matrix(data, alpha = .01, figsize = (10, 10), color = "red")
pass

# %% [markdown]
# Определим корреляцию параметров.

# %%
data.corr()
# Out:
#              ID        RI        Na        Mg        Al        Si         K  \
# ID     1.000000 -0.065721  0.380767 -0.647082  0.488475  0.052634 -0.002306
# RI    -0.065721  1.000000 -0.193436 -0.128118 -0.405671 -0.540010 -0.287900
# Na     0.380767 -0.193436  1.000000 -0.276486  0.157928 -0.068519 -0.265520
# Mg    -0.647082 -0.128118 -0.276486  1.000000 -0.480035 -0.160359  0.009397
# Al     0.488475 -0.405671  0.157928 -0.480035  1.000000 -0.009226  0.324484
# Si     0.052634 -0.540010 -0.068519 -0.160359 -0.009226  1.000000 -0.197684
# K     -0.002306 -0.287900 -0.265520  0.009397  0.324484 -0.197684  1.000000
# Ca     0.090257  0.812495 -0.275314 -0.444559 -0.260372 -0.210141 -0.318649
# Ba     0.451437  0.001062  0.327233 -0.492149  0.478936 -0.104361 -0.043790
# Fe    -0.078151  0.145791 -0.240802  0.086906 -0.076456 -0.097674 -0.009586
# class  0.878113 -0.161322  0.504983 -0.744004  0.597754  0.147767 -0.012765
#
#              Ca        Ba        Fe     class
# ...

# %% [markdown]
# Значения для RI и Ca лучше всех коррелируют, построим для них графики.

# %%
plt.figure(figsize = (10, 6))
plt.plot(data['Ca'], data['RI'], 'o', alpha = 0.5)
plt.xlabel('Ca')
plt.ylabel('Ri')
plt.title('RI vs Ca')
pass

# %%
plt.figure(figsize = (10, 6))
plt.scatter(data[data['class'] == 1]['Ca'],
            data[data['class'] == 1]['RI'],
            alpha = 0.3,
            label = '1',
            color = 'b')

plt.scatter(data[data['class'] == 2]['Ca'],
            data[data['class'] == 2]['RI'],
            alpha = 0.3,
            label = '2',
            color = 'r')

plt.xlabel('Ca')
plt.ylabel('RI')
plt.legend()
plt.grid()

# %% [markdown]
# Значения параметров 'RI' и 'Ca' у первого типа стекла принимают большие значения, чем у 2ого типа

# %%
data=data.drop("ID",axis = 1)
data
# Out:
#           RI     Na    Mg    Al     Si     K    Ca    Ba    Fe  class
# 0    1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.00  0.00      1
# 1    1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.00  0.00      1
# 2    1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.00  0.00      1
# 3    1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.00  0.00      1
# 4    1.51596  12.79  3.61  1.62  72.97  0.64  8.07  0.00  0.26      1
# 5    1.51743  13.30  3.60  1.14  73.09  0.58  8.17  0.00  0.00      1
# 6    1.51756  13.15  3.61  1.05  73.24  0.57  8.24  0.00  0.00      1
# 7    1.51918  14.04  3.58  1.37  72.08  0.56  8.30  0.00  0.00      1
# 8    1.51755  13.00  3.60  1.36  72.99  0.57  8.40  0.00  0.11      1
# 9    1.51571  12.72  3.46  1.56  73.20  0.67  8.09  0.00  0.24      1
# 10   1.51763  12.80  3.66  1.27  73.01  0.60  8.56  0.00  0.00      1
# 11   1.51589  12.88  3.43  1.40  73.28  0.69  8.05  0.00  0.24      1
# ...

# %% [markdown]
# # Подготовка данных

# %%
data['class'].dtype.name
# Out:
# 'int64'

# %% [markdown]
# Разделим признаки на категориальные и количественные:

# %%
categorical_columns = [c for c in data.columns if data[c].dtype.name == 'object']
numerical_columns   = [c for c in data.columns if data[c].dtype.name != 'object']
print(categorical_columns)
print(numerical_columns)
# Out:
# []
# ['RI', 'Na', 'Mg', 'Al', 'Si', 'K', 'Ca', 'Ba', 'Fe', 'class']

# %% [markdown]
# Выявим, есть ли пропущенные значения:

# %%
data[numerical_columns].count(axis = 0)
# Out:
# RI       213
# Na       213
# Mg       213
# Al       213
# Si       213
# K        213
# Ca       213
# Ba       213
# Fe       213
# class    213
# dtype: int64

# %% [markdown]
# Пропущенных значений нет.

# %% [markdown]
# # Векторизация данных

# %%
data_numerical = data[numerical_columns]
data_numerical.describe()
# Out:
#                RI          Na          Mg          Al          Si           K  \
# count  213.000000  213.000000  213.000000  213.000000  213.000000  213.000000
# mean     1.518353   13.406761    2.676056    1.446526   72.655023    0.499108
# std      0.003039    0.818371    1.440453    0.499882    0.774052    0.653035
# min      1.511150   10.730000    0.000000    0.290000   69.810000    0.000000
# 25%      1.516520   12.900000    2.090000    1.190000   72.280000    0.130000
# 50%      1.517680   13.300000    3.480000    1.360000   72.790000    0.560000
# 75%      1.519150   13.830000    3.600000    1.630000   73.090000    0.610000
# max      1.533930   17.380000    3.980000    3.500000   75.410000    6.210000
#
#                Ca          Ba          Fe       class
# count  213.000000  213.000000  213.000000  213.000000
# mean     8.957934    0.175869    0.057277    2.788732
# std      1.426435    0.498245    0.097589    2.105130
# ...

# %%
data_core = data['class'];
data_numerical = data_numerical.drop(('class'), axis = 1)
data_numerical.describe()
# Out:
#                RI          Na          Mg          Al          Si           K  \
# count  213.000000  213.000000  213.000000  213.000000  213.000000  213.000000
# mean     1.518353   13.406761    2.676056    1.446526   72.655023    0.499108
# std      0.003039    0.818371    1.440453    0.499882    0.774052    0.653035
# min      1.511150   10.730000    0.000000    0.290000   69.810000    0.000000
# 25%      1.516520   12.900000    2.090000    1.190000   72.280000    0.130000
# 50%      1.517680   13.300000    3.480000    1.360000   72.790000    0.560000
# 75%      1.519150   13.830000    3.600000    1.630000   73.090000    0.610000
# max      1.533930   17.380000    3.980000    3.500000   75.410000    6.210000
#
#                Ca          Ba          Fe
# count  213.000000  213.000000  213.000000
# mean     8.957934    0.175869    0.057277
# std      1.426435    0.498245    0.097589
# min      5.430000    0.000000    0.000000
# 25%      8.240000    0.000000    0.000000
# ...

# %% [markdown]
# # Нормализация данных

# %%
data_numerical = (data_numerical - data_numerical.mean(axis = 0))/data_numerical.std(axis = 0)
data_numerical.describe()
# Out:
#                  RI            Na            Mg            Al            Si  \
# count  2.130000e+02  2.130000e+02  2.130000e+02  2.130000e+02  2.130000e+02
# mean   2.878626e-13 -3.920703e-15  2.251720e-16 -1.215512e-15 -2.217475e-14
# std    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# min   -2.370526e+00 -3.270839e+00 -1.857787e+00 -2.313597e+00 -3.675495e+00
# 25%   -6.032461e-01 -6.192307e-01 -4.068555e-01 -5.131725e-01 -4.844940e-01
# 50%   -2.214874e-01 -1.304549e-01  5.581185e-01 -1.730924e-01  1.743766e-01
# 75%    2.622930e-01  5.171729e-01  6.414256e-01  3.670348e-01  5.619475e-01
# max    5.126425e+00  4.855058e+00  9.052314e-01  4.107916e+00  3.559163e+00
#
#                   K            Ca            Ba            Fe
# count  2.130000e+02  2.130000e+02  2.130000e+02  2.130000e+02
# mean   2.991869e-16 -3.944419e-16  9.548960e-16  3.752867e-16
# std    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# ...

# %% [markdown]
# Объединение данных в одну таблицу

# %%
data = pd.concat((data_numerical, data_core), axis = 1)
data.describe()
# Out:
#                  RI            Na            Mg            Al            Si  \
# count  2.130000e+02  2.130000e+02  2.130000e+02  2.130000e+02  2.130000e+02
# mean   2.878626e-13 -3.920703e-15  2.251720e-16 -1.215512e-15 -2.217475e-14
# std    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# min   -2.370526e+00 -3.270839e+00 -1.857787e+00 -2.313597e+00 -3.675495e+00
# 25%   -6.032461e-01 -6.192307e-01 -4.068555e-01 -5.131725e-01 -4.844940e-01
# 50%   -2.214874e-01 -1.304549e-01  5.581185e-01 -1.730924e-01  1.743766e-01
# 75%    2.622930e-01  5.171729e-01  6.414256e-01  3.670348e-01  5.619475e-01
# max    5.126425e+00  4.855058e+00  9.052314e-01  4.107916e+00  3.559163e+00
#
#                   K            Ca            Ba            Fe       class
# count  2.130000e+02  2.130000e+02  2.130000e+02  2.130000e+02  213.000000
# mean   2.991869e-16 -3.944419e-16  9.548960e-16  3.752867e-16    2.788732
# ...

# %% [markdown]
# # Задаем X и Y

# %%
X = data.drop(('class'), axis = 1)
y = data['class']
feature_names = X.columns

# %%
type(feature_names)
# Out:
# pandas.core.indexes.base.Index

# %%
feature_names
# Out:
# Index(['RI', 'Na', 'Mg', 'Al', 'Si', 'K', 'Ca', 'Ba', 'Fe'], dtype='object')

# %%
print(X.shape)
print(y.shape)
N, d = X.shape
# Out:
# (213, 9)
# (213,)

# %%
type(X)
# Out:
# pandas.core.frame.DataFrame

# %%
type(y)
# Out:
# pandas.core.series.Series

# %% [markdown]
# # Получим тестовые и обучающие выборки

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 1)

N_train, _ = X_train.shape 
N_test,  _ = X_test.shape 

print(N_train, N_test)
# Out:
# 149 64

# %% [markdown]
# # kNN

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors = 4)
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=1, n_neighbors=4, p=2,
#            weights='uniform')

# %%
knn
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=1, n_neighbors=4, p=2,
#            weights='uniform')

# %% [markdown]
# Подсчет средней ошибки

# %%
y_train_predict = knn.predict(X_train)
y_test_predict = knn.predict(X_test)

err_train = np.mean(y_train != y_train_predict)
err_test  = np.mean(y_test  != y_test_predict)

print(err_train, err_test)
# Out:
# 0.261744966443 0.28125

# %% [markdown]
# Ошибку возможно посчитать ещё одним способом:

# %%
err_test = 1 - knn.score(X_test, y_test)
err_test
# Out:
# 0.28125

# %% [markdown]
# С помощью метода confusion matrix вычисляем точность работы классификатора. Элемент матрицы (i, j) будет равен числу объектов из группы i, а предсказанных в группу j

# %%
from sklearn.metrics import confusion_matrix

print(confusion_matrix(y_test, y_test_predict))
# Out:
# [[19  4  0  0  0  0]
#  [ 5 15  0  2  0  0]
#  [ 4  2  1  0  0  0]
#  [ 0  0  0  2  0  0]
#  [ 0  0  0  0  2  0]
#  [ 0  1  0  0  0  7]]

# %% [markdown]
# Подбор параметров

# %%
from sklearn.model_selection import GridSearchCV
nnb = [1, 3, 5, 10, 15, 20, 25, 35, 45, 55]
knn = KNeighborsClassifier()
grid = GridSearchCV(knn, param_grid = {'n_neighbors': nnb}, cv=10)
grid.fit(X_train, y_train)

best_cv_err = 1 - grid.best_score_
best_n_neighbors = grid.best_estimator_.n_neighbors
print(best_cv_err, best_n_neighbors)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:605: Warning: The least populated class in y has only 7 members, which is too few. The minimum number of members in any class cannot be less than n_splits=10.
#   % (min_groups, self.n_splits)), Warning)
# 0.323943661972 1

# %%
knn = KNeighborsClassifier(n_neighbors = best_n_neighbors).fit(X_train, y_train)

err_train = np.mean(y_train != knn.predict(X_train))
err_test  = np.mean(y_test  != knn.predict(X_test))

print(err_train, err_test)
# Out:
# 0.0 0.203125

# %% [markdown]
# # Нейронные сети

# %% [markdown]
# C помощью нейронных сетей решим задачу классификации.

# %% [markdown]
# Разбиваем данные на обучающую и тестовую выборки

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.33, random_state = 7)
N_test, _ = X_test.shape

# %% [markdown]
# Обучение классификатора вида многослойного персептрона. Активационная функций: логистическая сигмоидальная f(x) = 1 / (1 + exp(-x)). Один скрытый слой с 5-ю нейронами

# %%
from sklearn.neural_network import MLPClassifier
mlp_model = MLPClassifier(hidden_layer_sizes = (5), solver = 'lbfgs', activation = 'logistic', random_state = 24)
mlp_model.fit(X_train, y_train)
# Out:
# MLPClassifier(activation='logistic', alpha=0.0001, batch_size='auto',
#        beta_1=0.9, beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=5, learning_rate='constant',
#        learning_rate_init=0.001, max_iter=200, momentum=0.9,
#        nesterovs_momentum=True, power_t=0.5, random_state=24, shuffle=True,
#        solver='lbfgs', tol=0.0001, validation_fraction=0.1, verbose=False,
#        warm_start=False)

# %% [markdown]
# Проверяка качества классификатора на основании его ошибки на тестовой и обучающей выборках

# %%
y_train_pred = mlp_model.predict(X_train)
y_test_pred = mlp_model.predict(X_test)

print(np.mean(y_train != y_train_pred), np.mean(y_test != y_test_pred))
# Out:
# 0.112676056338 0.380281690141

# %% [markdown]
# Ошибка на тестовой выборке выше, чем на обучающей, значит наблюдается переобучение. Увеличим количество нейронов на скрытом слое.

# %%
mlp_model = MLPClassifier(hidden_layer_sizes = (60), solver = 'lbfgs', activation = 'logistic', random_state = 24)
mlp_model.fit(X_train, y_train)
# Out:
# MLPClassifier(activation='logistic', alpha=0.0001, batch_size='auto',
#        beta_1=0.9, beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=60, learning_rate='constant',
#        learning_rate_init=0.001, max_iter=200, momentum=0.9,
#        nesterovs_momentum=True, power_t=0.5, random_state=24, shuffle=True,
#        solver='lbfgs', tol=0.0001, validation_fraction=0.1, verbose=False,
#        warm_start=False)

# %%
y_train_pred = mlp_model.predict(X_train)
y_test_pred = mlp_model.predict(X_test)

print(np.mean(y_train != y_train_pred), np.mean(y_test != y_test_pred))
# Out:
# 0.0 0.253521126761

# %% [markdown]
# Перебрав количество нейронов от 10 до 100 замечаем, что наименьшая ошибка наблюдается при количестве нейронов равном 50.Теперь попробуем использовать персептрон с двумя скрытыми слоями

# %%
mlp_model = MLPClassifier(hidden_layer_sizes = (50, 20), solver = 'lbfgs', activation = 'logistic', random_state = 24)
mlp_model.fit(X_train, y_train)
# Out:
# MLPClassifier(activation='logistic', alpha=0.0001, batch_size='auto',
#        beta_1=0.9, beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(50, 20), learning_rate='constant',
#        learning_rate_init=0.001, max_iter=200, momentum=0.9,
#        nesterovs_momentum=True, power_t=0.5, random_state=24, shuffle=True,
#        solver='lbfgs', tol=0.0001, validation_fraction=0.1, verbose=False,
#        warm_start=False)

# %%
y_train_pred = mlp_model.predict(X_train)
y_test_pred = mlp_model.predict(X_test)

print(np.mean(y_train != y_train_pred), np.mean(y_test != y_test_pred))
# Out:
# 0.0 0.253521126761

# %% [markdown]
# При проведении тестов не найдена ситуация, где не наблюдалось бы переобучение. Наименьшая ошибка наблюдается при количестве нейронов (50, 20) на двух скрытых слоях.

# %% [markdown]
# Построим график зависимости ошибок от количества нейронов в скрытом слое (1 скрытый слой)

# %%
neurs_arr_1 = np.arange(1, 100, 1)
test_err = []
train_err = []
for neurs in neurs_arr_1:
    mlp_model = MLPClassifier(hidden_layer_sizes = (neurs,), solver = 'lbfgs',
                              activation = 'logistic', random_state = 24)
    mlp_model.fit(X_train, y_train)

    y_train_pred = mlp_model.predict(X_train)
    y_test_pred = mlp_model.predict(X_test)
    train_err.append(np.mean(y_train != y_train_pred))
    test_err.append(np.mean(y_test != y_test_pred))

print("Минимальная ошибка:")
min_train_err = np.min(train_err)
min_test_err = np.min(test_err)
print(min_train_err, min_test_err)

print("Оптимальное количество нейронов:")
neurs_opt_1 = neurs_arr_1[test_err == min_test_err][0]
print(neurs_opt_1)

plt.figure(figsize = (10, 6))
plt.semilogx(neurs_arr_1, train_err, 'b-o', label = 'train')
plt.semilogx(neurs_arr_1, test_err, 'r-o', label = 'test')
plt.xlim([np.max(neurs_arr_1), np.min(neurs_arr_1)])
plt.title('Error vs. neurons count')
plt.xlabel('neurons')
plt.ylabel('error')
plt.legend()
pass
# Out:
# Минимальная ошибка:
# 0.0 0.197183098592
# Оптимальное количество нейронов:
# 43

# %% [markdown]
# Для оптимальной конфигурации нейронов наблюдается переобучение.

# %% [markdown]
# Построим график зависимости ошибок от количества нейронов в скрытых слоях (2 скрытых слоя с одинаковым количеством нейронов).

# %%
neurs_arr_2 = np.arange(10, 100, 1)
test_err = []
train_err = []
for neurs in neurs_arr_2:
    mlp_model = MLPClassifier(hidden_layer_sizes = (neurs, neurs), solver = 'lbfgs',
                              activation = 'logistic', random_state = 24)
    mlp_model.fit(X_train, y_train)

    y_train_pred = mlp_model.predict(X_train)
    y_test_pred = mlp_model.predict(X_test)
    train_err.append(np.mean(y_train != y_train_pred))
    test_err.append(np.mean(y_test != y_test_pred))

print("Минимальная ошибка:")
min_train_err = np.min(train_err)
min_test_err = np.min(test_err)
print(min_train_err, min_test_err)

print("Оптимальное количество нейронов:")
neurs_opt_2 = neurs_arr_2[test_err == min_test_err][0]
print(neurs_opt_2)

plt.figure(figsize = (10, 6))
plt.semilogx(neurs_arr_2, train_err, 'b-o', label = 'train')
plt.semilogx(neurs_arr_2, test_err, 'r-o', label = 'test')
plt.xlim([np.max(neurs_arr_2), np.min(neurs_arr_2)])
plt.title('Error vs. neurons count')
plt.xlabel('neurons')
plt.ylabel('error')
plt.legend()
pass
# Out:
# Минимальная ошибка:
# 0.0 0.225352112676
# Оптимальное количество нейронов:
# 56

# %% [markdown]
# Ошибка меньше на конфигурации с двухслойной нейронной сетью с 56 нейронами, значит будем использовать эту конфигурацию.

# %% [markdown]
# # Подбор параметра регуляризации alpha

# %%
alpha_arr = np.logspace(-3, 2, 30)
test_err = []
train_err = []
for alpha in alpha_arr:
    mlp_model = MLPClassifier(alpha = alpha, hidden_layer_sizes = (25, 5), 
                              solver = 'lbfgs', activation = 'logistic', random_state = 24)
    mlp_model.fit(X_train, y_train)

    y_train_pred = mlp_model.predict(X_train)
    y_test_pred = mlp_model.predict(X_test)
    train_err.append(np.mean(y_train != y_train_pred))
    test_err.append(np.mean(y_test != y_test_pred))

print("Минимальная ошибка:")
min_train_err = np.min(train_err)
min_test_err = np.min(test_err)
print(min_train_err, min_test_err)

print("Оптимальное значение alpha:")
alpha_opt = alpha_arr[test_err == min_test_err][0]
print(alpha_opt)

plt.figure(figsize = (10, 6))
plt.semilogx(alpha_arr, train_err, 'b-o', label = 'train')
plt.semilogx(alpha_arr, test_err, 'r-o', label = 'test')
plt.xlim([np.max(alpha_arr), np.min(alpha_arr)])
plt.title('Error vs. alpha')
plt.xlabel('alpha')
plt.ylabel('error')
plt.legend()
pass
# Out:
# Минимальная ошибка:
# 0.0 0.239436619718
# Оптимальное значение alpha:
# 0.0239502661999

# %% [markdown]
# # Классификатор на найденных оптимальных значениях

# %%
mlp_model = MLPClassifier(alpha = alpha_opt, hidden_layer_sizes = (25,5),
                          solver = 'lbfgs', activation = 'logistic', random_state = 24)
mlp_model.fit(X_train, y_train)

y_train_pred = mlp_model.predict(X_train)
y_test_pred = mlp_model.predict(X_test)

print("Ошибки на обучающей и тестовой выборках:")
print(np.mean(y_train != y_train_pred), np.mean(y_test != y_test_pred))
# Out:
# Ошибки на обучающей и тестовой выборках:
# 0.0 0.239436619718

# %% [markdown]
# Оптимальная конфигурация: alpha = 0.0239502661999 , нейронная сеть из двух слоев (50, 20). Присутсвует переобучение
